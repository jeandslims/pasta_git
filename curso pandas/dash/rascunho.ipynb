# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Vendedor': ['Ana', 'Bruno', 'Carla', 'Diego'],
    'Vendas': [150, 120, 180, 95]
})

# %%
df
# Out:
#   Vendedor  Vendas
# 0      Ana     150
# 1    Bruno     120
# 2    Carla     180
# 3    Diego      95
